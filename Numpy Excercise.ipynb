# %% [markdown]
# # Data Science Series Part - 1: Introduction to Numpy and Pandas

# %% [markdown]
# ## Numpy Excercise

# %% [markdown]
# #### 1. Import the numpy package as np

# %% [markdown]
# #### 2. Print the numpy version

# %% [markdown]
# #### 3. Create numpy array with datatype as int32

# %% [markdown]
# #### 4. Create numpy array with datatype as complex128

# %% [markdown]
# #### 5. Convert given numpy list

# %% [markdown]
# list1 = np.array([1, 2, 3, 4, 5]) ------> list1 = np.array([11, 22, 33, 44, 55])

# %%
list1 = np.array([1,2,3,4,5])

# %% [markdown]
# #### 6. Find mode,max of list1 and sum, product of list2

# %%
list1 = np.array([61,25,33,41,59)] 
list2 = np.array([40,66,np.nan,97,83)]

# %% [markdown]
# #### 7. Find nonzero elements of the list

# %%
list1 = np.array([4,9,5,7,0,9,4,6,5,0,0,5,2])

# %% [markdown]
# #### 8. Find even number from an array

# %%
list1 = np.array([4,9,5,7,0,9,4,6,5,0,0,5,2])

# %% [markdown]
# #### 9. One-dimentional slicing

# %%
list1 = np.arange(15, 40)

# %% [markdown]
# 1. Find values less than 34 and greater than 25
# 2. find values in reverse order
# 3. find values less than 19

# %% [markdown]
# #### 8. Two-dimentional slicing

# %% [markdown]
# Two dimentional array is given below. Find the arrays which highlighted by colors using slicing.

# %%
from IPython.display import Image
Image(filename='Two_dim_array.png', height=400, width=400)

# %% [markdown]
# 1. Slice list which are highlighted in yellow color
# 2. Slice list which are highlighted in red color
# 3. Slice list which are highlighted in green color
# 4. Slice list which are highlighted in blue color
# 5. Slice list which are highlighted in purple color

# %% [markdown]
# #### 9. Find mean, standard deviation and variance 5th column and 6th row of above image

# %% [markdown]
# #### 10. Create 5x5 matrix of ones
